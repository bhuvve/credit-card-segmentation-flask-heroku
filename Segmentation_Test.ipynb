# %% [markdown]
# ## Credit Card Customer Segmentation
# - This case requires developing a customer segmentation to define marketing strategy
# - Unsupervised Learning - There is no target variable

# %% [markdown]
# #### Tasks
# - Prepare intelligent KPI's
# - Provide detailed insights based on the analysis
# - Cluster Analysis
# - Provide strategic insights

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# - Load Dataset

# %%
creditcarddata = pd.read_csv("Data/CC GENERAL.csv")

# %%
creditcarddata.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES
# 0  C10001    40.900749           0.818182      95.40              0.00  \
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY
# 0                    95.4      0.000000             0.166667  \
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY
# 0                    0.000000                          0.083333  \
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT
# 0                0.000000                 0              2        1000.0  \
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
#use seaborn graph styple

plt.style.use("seaborn")
# Out:
# C:\Users\bhuvv\AppData\Local\Temp\ipykernel_13276\4093792729.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
### data dimensions

creditcarddata.shape
# Out:
# (8950, 18)

# %%
## Data Types
creditcarddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
### Checking for Missing Values

creditcarddata.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# - There are some missing values in CREDIT_LIMIT and MINIMUM_PAYMENTS

# %%
##Checking the missing value count for CREDIT LIMIT

creditcarddata['CREDIT_LIMIT'].isnull().value_counts()
# Out:
# CREDIT_LIMIT
# False    8949
# True        1
# Name: count, dtype: int64

# %%
##Checking missing value count for MINIMUM PAYMENTS

creditcarddata['MINIMUM_PAYMENTS'].isnull().value_counts()
# Out:
# MINIMUM_PAYMENTS
# False    8637
# True      313
# Name: count, dtype: int64

# %%
creditcarddata['MINIMUM_PAYMENTS'].isnull().value_counts().plot.barh()

plt.title("Missing Values in MINIMUM PAYMENTS")
plt.show()

# %% [markdown]
# - Descriptive Analysis of data

# %%
print(creditcarddata["MINIMUM_PAYMENTS"].describe())
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %%
## Intital descriptive analysis of the data

creditcarddata.describe(percentiles=[.25,0.50,0.75,0.90]).T
# Out:
#                                    count         mean          std        min
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000  \
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# PURCHASES_TRX                     8950.0    14.709832    24.857649   0.000000
# CREDIT_LIMIT                      8949.0  4494.449450  3638.815725  50.000000
# PAYMENTS                          8950.0  1733.143852  2895.063757   0.000000
# MINIMUM_PAYMENTS                  8637.0   864.206542  2372.446607   0.019163
# PRC_FULL_PAYMENT                  8950.0     0.153715     0.292499   0.000000
# TENURE                            8950.0    11.517318     1.338331   6.000000
#
#                                           25%          50%          75%
# BALANCE                            128.281915   873.385231  2054.140036  \
# BALANCE_FREQUENCY                    0.888889     1.000000     1.000000
# PURCHASES                           39.635000   361.280000  1110.130000
# ONEOFF_PURCHASES                     0.000000    38.000000   577.405000
# INSTALLMENTS_PURCHASES               0.000000    89.000000   468.637500
# CASH_ADVANCE                         0.000000     0.000000  1113.821139
# PURCHASES_FREQUENCY                  0.083333     0.500000     0.916667
# ONEOFF_PURCHASES_FREQUENCY           0.000000     0.083333     0.300000
# PURCHASES_INSTALLMENTS_FREQUENCY     0.000000     0.166667     0.750000
# CASH_ADVANCE_FREQUENCY               0.000000     0.000000     0.222222
# CASH_ADVANCE_TRX                     0.000000     0.000000     4.000000
# PURCHASES_TRX                        1.000000     7.000000    17.000000
# CREDIT_LIMIT                      1600.000000  3000.000000  6500.000000
# PAYMENTS                           383.276166   856.901546  1901.134317
# MINIMUM_PAYMENTS                   169.123707   312.343947   825.485459
# PRC_FULL_PAYMENT                     0.000000     0.000000     0.142857
# TENURE                              12.000000    12.000000    12.000000
#
#                                           90%          max
# BALANCE                           4338.563657  19043.13856
# BALANCE_FREQUENCY                    1.000000      1.00000
# PURCHASES                         2542.624000  49039.57000
# ONEOFF_PURCHASES                  1600.099000  40761.25000
# INSTALLMENTS_PURCHASES            1140.070000  22500.00000
# CASH_ADVANCE                      3065.534560  47137.21176
# PURCHASES_FREQUENCY                  1.000000      1.00000
# ONEOFF_PURCHASES_FREQUENCY           0.750000      1.00000
# PURCHASES_INSTALLMENTS_FREQUENCY     1.000000      1.00000
# CASH_ADVANCE_FREQUENCY               0.416667      1.50000
# CASH_ADVANCE_TRX                    10.000000    123.00000
# PURCHASES_TRX                       37.000000    358.00000
# CREDIT_LIMIT                      9500.000000  30000.00000
# PAYMENTS                          3923.906642  50721.48336
# MINIMUM_PAYMENTS                  1780.651744  76406.20752
# PRC_FULL_PAYMENT                     0.670000      1.00000
# TENURE                              12.000000     12.00000

# %% [markdown]
# ### Missing Value Treatment

# %%
##Checking the distribution of 'CREDIT LIMIT'

sns.boxplot(y = "CREDIT_LIMIT", data=creditcarddata)
plt.title("Box plot of CREDIT LIMIT")

plt.show()

# %% [markdown]
# - From the boxplot we have seen the data is skewed, so we will use median to impute the missing data

# %%
#Impute with median

creditcarddata['CREDIT_LIMIT'].fillna(creditcarddata['CREDIT_LIMIT'].median(),inplace = True)

# %%
#Rechecking whether imputing sucessfull or not
creditcarddata['CREDIT_LIMIT'].isnull().sum()
# Out:
# 0

# %%
##Checking the distribution of 'MINIMUM_PAYMENTS'

sns.boxplot(y = "MINIMUM_PAYMENTS", data=creditcarddata)
plt.title("Box plot of MINIMUM_PAYMENTS")

plt.show()

# %% [markdown]
# - From the boxplot we have seen the data is skewed, so we will use median to impute the missing data

# %%
#Impute with median

creditcarddata['MINIMUM_PAYMENTS'].fillna(creditcarddata['MINIMUM_PAYMENTS'].median(),inplace = True)

# %%
#Rechecking whether imputing sucessfull or not
creditcarddata['MINIMUM_PAYMENTS'].isnull().sum()
# Out:
# 0

# %% [markdown]
# **Observations**
# - There are 8950 observations and 18 features
# - 18 Numerical columns
# - There are missing values in 'CREDIT_LIMIT' and 'MINIMUM_PAYMENTS'
# - Data is skewed in CREDIT_LIMIT and MINIMUM_PAYMENTS
# - We have used median to impute the missing value data

# %% [markdown]
# ----
#
# ## Deriving New KPI
#
# ---

# %% [markdown]
# #### Monthly Average Purchase

# %%
creditcarddata["Monthly_Avg_Purchase"] = creditcarddata["PURCHASES"]/creditcarddata["TENURE"]

# %%
creditcarddata["Monthly_Avg_Purchase"].head()
# Out:
# 0      7.950000
# 1      0.000000
# 2     64.430833
# 3    124.916667
# 4      1.333333
# Name: Monthly_Avg_Purchase, dtype: float64

# %% [markdown]
# #### Monthly cash advance amount

# %%
creditcarddata["Monthly_Cash_Advance"] = creditcarddata["CASH_ADVANCE"]/creditcarddata["TENURE"]

# %% [markdown]
# ### Purchase Type

# %%
creditcarddata.loc[:,["ONEOFF_PURCHASES","INSTALLMENTS_PURCHASES"]].head()
# Out:
#    ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES
# 0              0.00                    95.4
# 1              0.00                     0.0
# 2            773.17                     0.0
# 3           1499.00                     0.0
# 4             16.00                     0.0

# %% [markdown]
# - Deriving the categorical variable based on user behaviour

# %%
def purchasetype(x):    
    if (x["ONEOFF_PURCHASES"] == 0) & (x["INSTALLMENTS_PURCHASES"] == 0):
        return("NONE")
    elif (x["ONEOFF_PURCHASES"] > 0) & (x["INSTALLMENTS_PURCHASES"] == 0):
        return("ONEOFF")
    elif (x["ONEOFF_PURCHASES"] == 0) & (x["INSTALLMENTS_PURCHASES"] > 0):
        return("INSTALLMENTS")
    elif (x["ONEOFF_PURCHASES"] > 0) & (x["INSTALLMENTS_PURCHASES"] > 0):
        return("BOTH_ONEOFF_INSTALLMENTS")

# %%
creditcarddata["Purchase_Type"] = creditcarddata.apply(purchasetype,axis=1)

# %%
creditcarddata["Purchase_Type"].value_counts()
# Out:
# Purchase_Type
# BOTH_ONEOFF_INSTALLMENTS    2774
# INSTALLMENTS                2260
# NONE                        2042
# ONEOFF                      1874
# Name: count, dtype: int64

# %% [markdown]
# ### Limit usage
#
# - Balance to credit limit ratio

# %%
creditcarddata["Balance_Credit_Ratio"] = creditcarddata["BALANCE"]/creditcarddata["CREDIT_LIMIT"]

# %%
creditcarddata.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES
# 0  C10001    40.900749           0.818182      95.40              0.00  \
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY
# 0                    95.4      0.000000             0.166667  \
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...
# 0                    0.000000                          0.083333  ...  \
# 1                    0.000000                          0.000000  ...
# 2                    1.000000                          0.000000  ...
# 3                    0.083333                          0.000000  ...
# 4                    0.083333                          0.000000  ...
#
#    PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS
# 0              2        1000.0   201.802084        139.509787  \
# 1              0        7000.0  4103.032597       1072.340217
# 2             12        7500.0   622.066742        627.284787
# 3              1        7500.0     0.000000        312.343947
# 4              1        1200.0   678.334763        244.791237
#
#    PRC_FULL_PAYMENT  TENURE  Monthly_Avg_Purchase  Monthly_Cash_Advance
# 0          0.000000      12              7.950000              0.000000  \
# 1          0.222222      12              0.000000            536.912124
# 2          0.000000      12             64.430833              0.000000
# 3          0.000000      12            124.916667             17.149001
# 4          0.000000      12              1.333333              0.000000
#
#    Purchase_Type  Balance_Credit_Ratio
# 0   INSTALLMENTS              0.040901
# 1           NONE              0.457495
# 2         ONEOFF              0.332687
# 3         ONEOFF              0.222223
# 4         ONEOFF              0.681429
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Payments to Minimum Payments Ratio
# - Total Payment Ratio calculate it by dividing your total monthly credit payments by the total minimum due

# %%
#added where clause to avoid division by zero

creditcarddata["Total_Payment_Ratio"] = np.where(creditcarddata["MINIMUM_PAYMENTS"] == 0,creditcarddata["MINIMUM_PAYMENTS"], creditcarddata["PAYMENTS"]/creditcarddata["MINIMUM_PAYMENTS"])

# %%
creditcarddata = creditcarddata.round(2)

# %%
creditcarddata.head()
# Out:
#   CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES
# 0  C10001    40.90               0.82      95.40              0.00  \
# 1  C10002  3202.47               0.91       0.00              0.00
# 2  C10003  2495.15               1.00     773.17            773.17
# 3  C10004  1666.67               0.64    1499.00           1499.00
# 4  C10005   817.71               1.00      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY
# 0                    95.4          0.00                 0.17  \
# 1                     0.0       6442.95                 0.00
# 2                     0.0          0.00                 1.00
# 3                     0.0        205.79                 0.08
# 4                     0.0          0.00                 0.08
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...
# 0                        0.00                              0.08  ...  \
# 1                        0.00                              0.00  ...
# 2                        1.00                              0.00  ...
# 3                        0.08                              0.00  ...
# 4                        0.08                              0.00  ...
#
#    CREDIT_LIMIT  PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0        1000.0    201.80            139.51              0.00      12  \
# 1        7000.0   4103.03           1072.34              0.22      12
# 2        7500.0    622.07            627.28              0.00      12
# 3        7500.0      0.00            312.34              0.00      12
# 4        1200.0    678.33            244.79              0.00      12
#
#    Monthly_Avg_Purchase  Monthly_Cash_Advance  Purchase_Type
# 0                  7.95                  0.00   INSTALLMENTS  \
# 1                  0.00                536.91           NONE
# 2                 64.43                  0.00         ONEOFF
# 3                124.92                 17.15         ONEOFF
# 4                  1.33                  0.00         ONEOFF
#
#    Balance_Credit_Ratio  Total_Payment_Ratio
# 0                  0.04                 1.45
# 1                  0.46                 3.83
# 2                  0.33                 0.99
# 3                  0.22                 0.00
# 4                  0.68                 2.77
#
# [5 rows x 23 columns]

# %% [markdown]
# ---
#
# ## Insights from new KPIs
#
# ---

# %%
#Average Total Payment Ratio  for each purchase type

x = creditcarddata[["Purchase_Type","Total_Payment_Ratio"]].groupby(["Purchase_Type"]).agg("mean").reset_index()
x
# Out:
#               Purchase_Type  Total_Payment_Ratio
# 0  BOTH_ONEOFF_INSTALLMENTS             7.237087
# 1              INSTALLMENTS            13.259013
# 2                      NONE            10.087311
# 3                    ONEOFF             5.571051

# %%
#checking the total payment ratio based on purchase type

creditcarddata.groupby("Purchase_Type").apply(lambda x: np.mean(x["Total_Payment_Ratio"])).plot.barh()
plt.show()

# %%
creditcarddata.groupby('Purchase_Type').apply(lambda x : np.mean(x['Monthly_Cash_Advance'])).plot.barh()
plt.show()

# %% [markdown]
# #### Insights
# - Customers with installment payments are paying dues
# - Customers who do not do ONOFF or INSTALLMENTS take more cash advance
# - Customers with installment purchases have good credit score

# %%
#balance to credit ratio (limit usage ratio) is more then the customers will have good credit score

creditcarddata.groupby("Purchase_Type").apply(lambda x: np.mean(x["Balance_Credit_Ratio"])).plot.barh()
plt.show()

# %%
#checking the monthly average purchases based on payment type
creditcarddata.groupby("Purchase_Type").apply(lambda x: np.mean(x["Monthly_Avg_Purchase"])).plot.barh()
plt.xlabel("Monthly Average Purchase")
plt.show()

# %% [markdown]
# Customers using both oneoff and installment payment has more monthly average purchases

# %% [markdown]
# ### Data Segregation
# - Handling Categorical Variable

# %%
#getting the numeric variable names and data
creditcarddata_numeric = creditcarddata._get_numeric_data()

# %%
numeric_variable_names =  list(creditcarddata_numeric.columns)

# %%
numeric_variable_names
# Out:
# ['BALANCE',
#  'BALANCE_FREQUENCY',
#  'PURCHASES',
#  'ONEOFF_PURCHASES',
#  'INSTALLMENTS_PURCHASES',
#  'CASH_ADVANCE',
#  'PURCHASES_FREQUENCY',
#  'ONEOFF_PURCHASES_FREQUENCY',
#  'PURCHASES_INSTALLMENTS_FREQUENCY',
#  'CASH_ADVANCE_FREQUENCY',
#  'CASH_ADVANCE_TRX',
#  'PURCHASES_TRX',
#  'CREDIT_LIMIT',
#  'PAYMENTS',
#  'MINIMUM_PAYMENTS',
#  'PRC_FULL_PAYMENT',
#  'TENURE',
#  'Monthly_Avg_Purchase',
#  'Monthly_Cash_Advance',
#  'Balance_Credit_Ratio',
#  'Total_Payment_Ratio']

# %% [markdown]
# There are many variables having extreme values, i am doing the log transformation on the dataset to remove the outlier effect

# %%
#log transformation

credit_log = creditcarddata_numeric.apply(lambda x: np.log(x + 1))

# %%
credit_log.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES
# count  8950.000000        8950.000000  8950.000000       8950.000000  \
# mean      6.161638           0.619992     4.899647          3.204274
# std       2.013303           0.148856     2.916872          3.246365
# min       0.000000           0.000000     0.000000          0.000000
# 25%       4.861981           0.636577     3.704627          0.000000
# 50%       6.773521           0.693147     5.892417          3.663562
# 75%       7.628098           0.693147     7.013133          6.360274
# max       9.854515           0.693147    10.800403         10.615512
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY
# count             8950.000000   8950.000000          8950.000000  \
# mean                 3.352403      3.319086             0.361112
# std                  3.082973      3.566298             0.277560
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.076961
# 50%                  4.499810      0.000000             0.405465
# 75%                  6.151961      7.016450             0.652325
# max                 10.021315     10.760839             0.693147
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY
# count                 8950.000000                       8950.000000  \
# mean                     0.158423                          0.270125
# std                      0.216834                          0.281965
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.076961                          0.157004
# 75%                      0.262364                          0.559616
# max                      0.693147                          0.693147
#
#        CASH_ADVANCE_FREQUENCY  ...  PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS
# count             8950.000000  ...    8950.000000   8950.000000  8950.000000  \
# mean                 0.113286  ...       1.894731      8.094825     6.624541
# std                  0.156823  ...       1.373856      0.819629     1.591761
# min                  0.000000  ...       0.000000      3.931826     0.000000
# 25%                  0.000000  ...       0.693147      7.378384     5.951352
# 50%                  0.000000  ...       2.079442      8.006701     6.754488
# 75%                  0.198851  ...       2.890372      8.779711     7.550732
# max                  0.916291  ...       5.883322     10.308986    10.834124
#
#        MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE  Monthly_Avg_Purchase
# count       8950.000000       8950.000000  8950.000000           8950.000000  \
# mean           5.916079          0.117550     2.519680              3.050872
# std            1.169927          0.211692     0.130367              2.002826
# min            0.019803          0.000000     1.945910              0.000000
# 25%            5.146666          0.000000     2.564949              1.481032
# 50%            5.747289          0.000000     2.564949              3.494536
# 75%            6.671669          0.131028     2.564949              4.587286
# max           11.243832          0.693147     2.564949              8.315721
#
#        Monthly_Cash_Advance  Balance_Credit_Ratio  Total_Payment_Ratio
# count           8950.000000           8950.000000          8950.000000
# mean               2.163969              0.296065             1.357595
# std                2.429742              0.250341             0.940158
# min                0.000000              0.000000             0.000000
# 25%                0.000000              0.039221             0.647103
# 50%                0.000000              0.262364             1.108563
# 75%                4.606045              0.542324             1.953028
# max                8.276166              2.827905             8.830767
#
# [8 rows x 21 columns]

# %%
#categorical variable names
catergorical_variable_names = [x for x in list(creditcarddata.columns) if x not in numeric_variable_names]

# %%
catergorical_variable_names
# Out:
# ['CUST_ID', 'Purchase_Type']

# %%
#removing the customer id as it is not significant
catergorical_variable_names.remove("CUST_ID")

# %% [markdown]
# - Converting to Dummy Variables

# %%
dummies = pd.get_dummies(creditcarddata[catergorical_variable_names])

# %%
dummies.head()
# Out:
#    Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_INSTALLMENTS
# 0                                   False                        True  \
# 1                                   False                       False
# 2                                   False                       False
# 3                                   False                       False
# 4                                   False                       False
#
#    Purchase_Type_NONE  Purchase_Type_ONEOFF
# 0               False                 False
# 1                True                 False
# 2               False                  True
# 3               False                  True
# 4               False                  True

# %%
pd.concat([creditcarddata,dummies],axis=1).head()
# Out:
#   CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES
# 0  C10001    40.90               0.82      95.40              0.00  \
# 1  C10002  3202.47               0.91       0.00              0.00
# 2  C10003  2495.15               1.00     773.17            773.17
# 3  C10004  1666.67               0.64    1499.00           1499.00
# 4  C10005   817.71               1.00      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY
# 0                    95.4          0.00                 0.17  \
# 1                     0.0       6442.95                 0.00
# 2                     0.0          0.00                 1.00
# 3                     0.0        205.79                 0.08
# 4                     0.0          0.00                 0.08
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  TENURE
# 0                        0.00                              0.08  ...      12  \
# 1                        0.00                              0.00  ...      12
# 2                        1.00                              0.00  ...      12
# 3                        0.08                              0.00  ...      12
# 4                        0.08                              0.00  ...      12
#
#    Monthly_Avg_Purchase  Monthly_Cash_Advance  Purchase_Type
# 0                  7.95                  0.00   INSTALLMENTS  \
# 1                  0.00                536.91           NONE
# 2                 64.43                  0.00         ONEOFF
# 3                124.92                 17.15         ONEOFF
# 4                  1.33                  0.00         ONEOFF
#
#    Balance_Credit_Ratio  Total_Payment_Ratio
# 0                  0.04                 1.45  \
# 1                  0.46                 3.83
# 2                  0.33                 0.99
# 3                  0.22                 0.00
# 4                  0.68                 2.77
#
#    Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_INSTALLMENTS
# 0                                   False                        True  \
# 1                                   False                       False
# 2                                   False                       False
# 3                                   False                       False
# 4                                   False                       False
#
#    Purchase_Type_NONE  Purchase_Type_ONEOFF
# 0               False                 False
# 1                True                 False
# 2               False                  True
# 3               False                  True
# 4               False                  True
#
# [5 rows x 27 columns]

# %%
#keeping an orignal data copy

creditcarddata_org = pd.concat([creditcarddata,dummies],axis=1)

# %%
#merging the log data and dummies data
creditcarddata_merged = pd.concat([credit_log,dummies],axis = 1)

# %%
##dropping the variables used to create the KPI
var_names = ["BALANCE","PURCHASES","PAYMENTS","MINIMUM_PAYMENTS","PRC_FULL_PAYMENT","TENURE","CASH_ADVANCE","CREDIT_LIMIT"]


creditcarddata_new = creditcarddata_merged[[x for x in creditcarddata_merged.columns if x not in var_names]]

# %%
creditcarddata_new.head()
# Out:
#    BALANCE_FREQUENCY  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES
# 0           0.598837          0.000000                4.568506  \
# 1           0.647103          0.000000                0.000000
# 2           0.693147          6.651791                0.000000
# 3           0.494696          7.313220                0.000000
# 4           0.693147          2.833213                0.000000
#
#    PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY
# 0             0.157004                    0.000000  \
# 1             0.000000                    0.000000
# 2             0.693147                    0.693147
# 3             0.076961                    0.076961
# 4             0.076961                    0.076961
#
#    PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX
# 0                          0.076961                0.000000          0.000000  \
# 1                          0.000000                0.223144          1.609438
# 2                          0.000000                0.000000          0.000000
# 3                          0.000000                0.076961          0.693147
# 4                          0.000000                0.000000          0.000000
#
#    PURCHASES_TRX  Monthly_Avg_Purchase  Monthly_Cash_Advance
# 0       1.098612              2.191654              0.000000  \
# 1       0.000000              0.000000              6.287691
# 2       2.564949              4.180981              0.000000
# 3       0.693147              4.835647              2.898671
# 4       0.693147              0.845868              0.000000
#
#    Balance_Credit_Ratio  Total_Payment_Ratio
# 0              0.039221             0.896088  \
# 1              0.378436             1.574846
# 2              0.285179             0.688135
# 3              0.198851             0.000000
# 4              0.518794             1.327075
#
#    Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_INSTALLMENTS
# 0                                   False                        True  \
# 1                                   False                       False
# 2                                   False                       False
# 3                                   False                       False
# 4                                   False                       False
#
#    Purchase_Type_NONE  Purchase_Type_ONEOFF
# 0               False                 False
# 1                True                 False
# 2               False                  True
# 3               False                  True
# 4               False                  True

# %%
#datatypes of new dataframe

creditcarddata_new.dtypes
# Out:
# BALANCE_FREQUENCY                         float64
# ONEOFF_PURCHASES                          float64
# INSTALLMENTS_PURCHASES                    float64
# PURCHASES_FREQUENCY                       float64
# ONEOFF_PURCHASES_FREQUENCY                float64
# PURCHASES_INSTALLMENTS_FREQUENCY          float64
# CASH_ADVANCE_FREQUENCY                    float64
# CASH_ADVANCE_TRX                          float64
# PURCHASES_TRX                             float64
# Monthly_Avg_Purchase                      float64
# Monthly_Cash_Advance                      float64
# Balance_Credit_Ratio                      float64
# Total_Payment_Ratio                       float64
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS       bool
# Purchase_Type_INSTALLMENTS                   bool
# Purchase_Type_NONE                           bool
# Purchase_Type_ONEOFF                         bool
# dtype: object

# %% [markdown]
# ### Check for multicollinearity

# %%
#correlation matrix

creditcarddata_new.corr()
# Out:
#                                         BALANCE_FREQUENCY  ONEOFF_PURCHASES
# BALANCE_FREQUENCY                                1.000000          0.140011  \
# ONEOFF_PURCHASES                                 0.140011          1.000000
# INSTALLMENTS_PURCHASES                           0.110737          0.161434
# PURCHASES_FREQUENCY                              0.212020          0.393549
# ONEOFF_PURCHASES_FREQUENCY                       0.199246          0.812792
# PURCHASES_INSTALLMENTS_FREQUENCY                 0.162496          0.097203
# CASH_ADVANCE_FREQUENCY                           0.194964         -0.128254
# CASH_ADVANCE_TRX                                 0.191120         -0.144803
# PURCHASES_TRX                                    0.197661          0.574393
# Monthly_Avg_Purchase                             0.136655          0.712305
# Monthly_Cash_Advance                             0.153206         -0.182490
# Balance_Credit_Ratio                             0.452558         -0.063056
# Total_Payment_Ratio                             -0.153108          0.236802
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS           0.191332          0.661126
# Purchase_Type_INSTALLMENTS                      -0.134297         -0.573717
# Purchase_Type_NONE                               0.011392         -0.536671
# Purchase_Type_ONEOFF                            -0.085826          0.414662
#
#                                         INSTALLMENTS_PURCHASES
# BALANCE_FREQUENCY                                     0.110737  \
# ONEOFF_PURCHASES                                      0.161434
# INSTALLMENTS_PURCHASES                                1.000000
# PURCHASES_FREQUENCY                                   0.804250
# ONEOFF_PURCHASES_FREQUENCY                            0.191702
# PURCHASES_INSTALLMENTS_FREQUENCY                      0.905355
# CASH_ADVANCE_FREQUENCY                               -0.309380
# CASH_ADVANCE_TRX                                     -0.335621
# PURCHASES_TRX                                         0.782683
# Monthly_Avg_Purchase                                  0.687568
# Monthly_Cash_Advance                                 -0.377478
# Balance_Credit_Ratio                                 -0.217464
# Total_Payment_Ratio                                   0.185808
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS                0.607277
# Purchase_Type_INSTALLMENTS                            0.448744
# Purchase_Type_NONE                                   -0.591238
# Purchase_Type_ONEOFF                                 -0.559631
#
#                                         PURCHASES_FREQUENCY
# BALANCE_FREQUENCY                                  0.212020  \
# ONEOFF_PURCHASES                                   0.393549
# INSTALLMENTS_PURCHASES                             0.804250
# PURCHASES_FREQUENCY                                1.000000
# ONEOFF_PURCHASES_FREQUENCY                         0.503709
# PURCHASES_INSTALLMENTS_FREQUENCY                   0.857019
# CASH_ADVANCE_FREQUENCY                            -0.344712
# CASH_ADVANCE_TRX                                  -0.382300
# PURCHASES_TRX                                      0.921747
# Monthly_Avg_Purchase                               0.816756
# Monthly_Cash_Advance                              -0.433223
# Balance_Credit_Ratio                              -0.232964
# Total_Payment_Ratio                                0.196354
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS             0.521632
# Purchase_Type_INSTALLMENTS                         0.309963
# Purchase_Type_NONE                                -0.707119
# Purchase_Type_ONEOFF                              -0.194572
#
#                                         ONEOFF_PURCHASES_FREQUENCY
# BALANCE_FREQUENCY                                         0.199246  \
# ONEOFF_PURCHASES                                          0.812792
# INSTALLMENTS_PURCHASES                                    0.191702
# PURCHASES_FREQUENCY                                       0.503709
# ONEOFF_PURCHASES_FREQUENCY                                1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                          0.143712
# CASH_ADVANCE_FREQUENCY                                   -0.122523
# CASH_ADVANCE_TRX                                         -0.145779
# PURCHASES_TRX                                             0.621777
# Monthly_Avg_Purchase                                      0.624033
# Monthly_Cash_Advance                                     -0.178047
# Balance_Credit_Ratio                                     -0.080859
# Total_Payment_Ratio                                       0.259715
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS                    0.555684
# Purchase_Type_INSTALLMENTS                               -0.424674
# Purchase_Type_NONE                                       -0.397252
# Purchase_Type_ONEOFF                                      0.231569
#
#                                         PURCHASES_INSTALLMENTS_FREQUENCY
# BALANCE_FREQUENCY                                               0.162496  \
# ONEOFF_PURCHASES                                                0.097203
# INSTALLMENTS_PURCHASES                                          0.905355
# PURCHASES_FREQUENCY                                             0.857019
# ONEOFF_PURCHASES_FREQUENCY                                      0.143712
# PURCHASES_INSTALLMENTS_FREQUENCY                                1.000000
# CASH_ADVANCE_FREQUENCY                                         -0.290063
# CASH_ADVANCE_TRX                                               -0.315110
# PURCHASES_TRX                                                   0.769830
# Monthly_Avg_Purchase                                            0.613860
# Monthly_Cash_Advance                                           -0.354119
# Balance_Credit_Ratio                                           -0.191249
# Total_Payment_Ratio                                             0.141595
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS                          0.486772
# Purchase_Type_INSTALLMENTS                                      0.446448
# Purchase_Type_NONE                                             -0.520620
# Purchase_Type_ONEOFF                                           -0.493043
#
#                                         CASH_ADVANCE_FREQUENCY
# BALANCE_FREQUENCY                                     0.194964  \
# ONEOFF_PURCHASES                                     -0.128254
# INSTALLMENTS_PURCHASES                               -0.309380
# PURCHASES_FREQUENCY                                  -0.344712
# ONEOFF_PURCHASES_FREQUENCY                           -0.122523
# PURCHASES_INSTALLMENTS_FREQUENCY                     -0.290063
# CASH_ADVANCE_FREQUENCY                                1.000000
# CASH_ADVANCE_TRX                                      0.936110
# PURCHASES_TRX                                        -0.326467
# Monthly_Avg_Purchase                                 -0.340227
# Monthly_Cash_Advance                                  0.825831
# Balance_Credit_Ratio                                  0.432835
# Total_Payment_Ratio                                  -0.130852
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS               -0.103763
# Purchase_Type_INSTALLMENTS                           -0.252529
# Purchase_Type_NONE                                    0.402654
# Purchase_Type_ONEOFF                                 -0.027705
#
#                                         CASH_ADVANCE_TRX  PURCHASES_TRX
# BALANCE_FREQUENCY                               0.191120       0.197661  \
# ONEOFF_PURCHASES                               -0.144803       0.574393
# INSTALLMENTS_PURCHASES                         -0.335621       0.782683
# PURCHASES_FREQUENCY                            -0.382300       0.921747
# ONEOFF_PURCHASES_FREQUENCY                     -0.145779       0.621777
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.315110       0.769830
# CASH_ADVANCE_FREQUENCY                          0.936110      -0.326467
# CASH_ADVANCE_TRX                                1.000000      -0.357895
# PURCHASES_TRX                                  -0.357895       1.000000
# Monthly_Avg_Purchase                           -0.378009       0.899851
# Monthly_Cash_Advance                            0.902805      -0.414204
# Balance_Credit_Ratio                            0.467670      -0.194133
# Total_Payment_Ratio                            -0.146754       0.237142
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS         -0.109572       0.620589
# Purchase_Type_INSTALLMENTS                     -0.279532       0.161920
# Purchase_Type_NONE                              0.448072      -0.749516
# Purchase_Type_ONEOFF                           -0.039111      -0.105244
#
#                                         Monthly_Avg_Purchase
# BALANCE_FREQUENCY                                   0.136655  \
# ONEOFF_PURCHASES                                    0.712305
# INSTALLMENTS_PURCHASES                              0.687568
# PURCHASES_FREQUENCY                                 0.816756
# ONEOFF_PURCHASES_FREQUENCY                          0.624033
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.613860
# CASH_ADVANCE_FREQUENCY                             -0.340227
# CASH_ADVANCE_TRX                                   -0.378009
# PURCHASES_TRX                                       0.899851
# Monthly_Avg_Purchase                                1.000000
# Monthly_Cash_Advance                               -0.426931
# Balance_Credit_Ratio                               -0.223222
# Total_Payment_Ratio                                 0.290685
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS              0.573881
# Purchase_Type_INSTALLMENTS                          0.089252
# Purchase_Type_NONE                                 -0.828241
# Purchase_Type_ONEOFF                                0.106638
#
#                                         Monthly_Cash_Advance
# BALANCE_FREQUENCY                                   0.153206  \
# ONEOFF_PURCHASES                                   -0.182490
# INSTALLMENTS_PURCHASES                             -0.377478
# PURCHASES_FREQUENCY                                -0.433223
# ONEOFF_PURCHASES_FREQUENCY                         -0.178047
# PURCHASES_INSTALLMENTS_FREQUENCY                   -0.354119
# CASH_ADVANCE_FREQUENCY                              0.825831
# CASH_ADVANCE_TRX                                    0.902805
# PURCHASES_TRX                                      -0.414204
# Monthly_Avg_Purchase                               -0.426931
# Monthly_Cash_Advance                                1.000000
# Balance_Credit_Ratio                                0.451879
# Total_Payment_Ratio                                -0.128390
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS             -0.144070
# Purchase_Type_INSTALLMENTS                         -0.295670
# Purchase_Type_NONE                                  0.516029
# Purchase_Type_ONEOFF                               -0.052756
#
#                                         Balance_Credit_Ratio
# BALANCE_FREQUENCY                                   0.452558  \
# ONEOFF_PURCHASES                                   -0.063056
# INSTALLMENTS_PURCHASES                             -0.217464
# PURCHASES_FREQUENCY                                -0.232964
# ONEOFF_PURCHASES_FREQUENCY                         -0.080859
# PURCHASES_INSTALLMENTS_FREQUENCY                   -0.191249
# CASH_ADVANCE_FREQUENCY                              0.432835
# CASH_ADVANCE_TRX                                    0.467670
# PURCHASES_TRX                                      -0.194133
# Monthly_Avg_Purchase                               -0.223222
# Monthly_Cash_Advance                                0.451879
# Balance_Credit_Ratio                                1.000000
# Total_Payment_Ratio                                -0.469817
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS             -0.050519
# Purchase_Type_INSTALLMENTS                         -0.213540
# Purchase_Type_NONE                                  0.285268
# Purchase_Type_ONEOFF                               -0.008784
#
#                                         Total_Payment_Ratio
# BALANCE_FREQUENCY                                 -0.153108  \
# ONEOFF_PURCHASES                                   0.236802
# INSTALLMENTS_PURCHASES                             0.185808
# PURCHASES_FREQUENCY                                0.196354
# ONEOFF_PURCHASES_FREQUENCY                         0.259715
# PURCHASES_INSTALLMENTS_FREQUENCY                   0.141595
# CASH_ADVANCE_FREQUENCY                            -0.130852
# CASH_ADVANCE_TRX                                  -0.146754
# PURCHASES_TRX                                      0.237142
# Monthly_Avg_Purchase                               0.290685
# Monthly_Cash_Advance                              -0.128390
# Balance_Credit_Ratio                              -0.469817
# Total_Payment_Ratio                                1.000000
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS             0.195427
# Purchase_Type_INSTALLMENTS                        -0.066844
# Purchase_Type_NONE                                -0.126677
# Purchase_Type_ONEOFF                              -0.020102
#
#                                         Purchase_Type_BOTH_ONEOFF_INSTALLMENTS
# BALANCE_FREQUENCY                                                     0.191332  \
# ONEOFF_PURCHASES                                                      0.661126
# INSTALLMENTS_PURCHASES                                                0.607277
# PURCHASES_FREQUENCY                                                   0.521632
# ONEOFF_PURCHASES_FREQUENCY                                            0.555684
# PURCHASES_INSTALLMENTS_FREQUENCY                                      0.486772
# CASH_ADVANCE_FREQUENCY                                               -0.103763
# CASH_ADVANCE_TRX                                                     -0.109572
# PURCHASES_TRX                                                         0.620589
# Monthly_Avg_Purchase                                                  0.573881
# Monthly_Cash_Advance                                                 -0.144070
# Balance_Credit_Ratio                                                 -0.050519
# Total_Payment_Ratio                                                   0.195427
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS                                1.000000
# Purchase_Type_INSTALLMENTS                                           -0.389530
# Purchase_Type_NONE                                                   -0.364377
# Purchase_Type_ONEOFF                                                 -0.344898
#
#                                         Purchase_Type_INSTALLMENTS
# BALANCE_FREQUENCY                                        -0.134297  \
# ONEOFF_PURCHASES                                         -0.573717
# INSTALLMENTS_PURCHASES                                    0.448744
# PURCHASES_FREQUENCY                                       0.309963
# ONEOFF_PURCHASES_FREQUENCY                               -0.424674
# PURCHASES_INSTALLMENTS_FREQUENCY                          0.446448
# CASH_ADVANCE_FREQUENCY                                   -0.252529
# CASH_ADVANCE_TRX                                         -0.279532
# PURCHASES_TRX                                             0.161920
# Monthly_Avg_Purchase                                      0.089252
# Monthly_Cash_Advance                                     -0.295670
# Balance_Credit_Ratio                                     -0.213540
# Total_Payment_Ratio                                      -0.066844
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS                   -0.389530
# Purchase_Type_INSTALLMENTS                                1.000000
# Purchase_Type_NONE                                       -0.316004
# Purchase_Type_ONEOFF                                     -0.299111
#
#                                         Purchase_Type_NONE
# BALANCE_FREQUENCY                                 0.011392  \
# ONEOFF_PURCHASES                                 -0.536671
# INSTALLMENTS_PURCHASES                           -0.591238
# PURCHASES_FREQUENCY                              -0.707119
# ONEOFF_PURCHASES_FREQUENCY                       -0.397252
# PURCHASES_INSTALLMENTS_FREQUENCY                 -0.520620
# CASH_ADVANCE_FREQUENCY                            0.402654
# CASH_ADVANCE_TRX                                  0.448072
# PURCHASES_TRX                                    -0.749516
# Monthly_Avg_Purchase                             -0.828241
# Monthly_Cash_Advance                              0.516029
# Balance_Credit_Ratio                              0.285268
# Total_Payment_Ratio                              -0.126677
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS           -0.364377
# Purchase_Type_INSTALLMENTS                       -0.316004
# Purchase_Type_NONE                                1.000000
# Purchase_Type_ONEOFF                             -0.279797
#
#                                         Purchase_Type_ONEOFF
# BALANCE_FREQUENCY                                  -0.085826
# ONEOFF_PURCHASES                                    0.414662
# INSTALLMENTS_PURCHASES                             -0.559631
# PURCHASES_FREQUENCY                                -0.194572
# ONEOFF_PURCHASES_FREQUENCY                          0.231569
# PURCHASES_INSTALLMENTS_FREQUENCY                   -0.493043
# CASH_ADVANCE_FREQUENCY                             -0.027705
# CASH_ADVANCE_TRX                                   -0.039111
# PURCHASES_TRX                                      -0.105244
# Monthly_Avg_Purchase                                0.106638
# Monthly_Cash_Advance                               -0.052756
# Balance_Credit_Ratio                               -0.008784
# Total_Payment_Ratio                                -0.020102
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS             -0.344898
# Purchase_Type_INSTALLMENTS                         -0.299111
# Purchase_Type_NONE                                 -0.279797
# Purchase_Type_ONEOFF                                1.000000

# %%
#creating a heatmap for better visualization
plt.figure(figsize=(10,8))
sns.heatmap(creditcarddata_new.corr(),annot=True,fmt=".2f",cmap="viridis")
plt.show()

# %% [markdown]
# <big>
# - Heat map shows that many features are co-related so applying dimension reduction wull help negating multi-colinearity in data.
# </big>
#
# - Before applying the PCA we will standardize data to avoid effect of scale on the result. Scaling will make all features with equal weight.

# %% [markdown]
# ### Standardization of data

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Create an object

sc = StandardScaler()

# %%
creditcard_scaled = sc.fit_transform(creditcarddata_new)

# %%
pd.DataFrame(creditcard_scaled).describe()
# Out:
#                  0            1             2             3             4
# count  8.950000e+03  8950.000000  8.950000e+03  8.950000e+03  8.950000e+03  \
# mean   4.382342e-16     0.000000  1.034058e-16 -9.526830e-18  1.714829e-16
# std    1.000056e+00     1.000056  1.000056e+00  1.000056e+00  1.000056e+00
# min   -4.165266e+00    -0.987090 -1.087454e+00 -1.301095e+00 -7.306590e-01
# 25%    1.114241e-01    -0.987090 -1.087454e+00 -1.023803e+00 -7.306590e-01
# 50%    4.914786e-01     0.141485  3.721960e-01  1.598063e-01 -3.757081e-01
# 75%    4.914786e-01     0.972218  9.081215e-01  1.049250e+00  4.793874e-01
# max    4.914786e-01     2.283062  2.163264e+00  1.196332e+00  2.466195e+00
#
#                  5             6             7             8             9
# count  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  \
# mean  -1.143220e-16  6.986342e-17 -5.795488e-17  1.397268e-16 -4.922195e-17
# std    1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00
# min   -9.580617e-01 -7.224223e-01 -8.100687e-01 -1.379210e+00 -1.523368e+00
# 25%   -9.580617e-01 -7.224223e-01 -8.100687e-01 -8.746552e-01 -7.838563e-01
# 50%   -4.012107e-01 -7.224223e-01 -8.100687e-01  1.344545e-01  2.215312e-01
# 75%    1.026748e+00  5.456405e-01  7.846025e-01  7.247459e-01  7.671657e-01
# max    1.500349e+00  5.120722e+00  3.965987e+00  2.903371e+00  2.628856e+00
#
#                  10            11            12            13            14
# count  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  8.950000e+03  \
# mean  -4.842805e-17 -6.033659e-17  1.262305e-16  4.445854e-17 -6.986342e-17
# std    1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00  1.000056e+00
# min   -8.906669e-01 -1.182714e+00 -1.444087e+00 -6.701925e-01 -5.812208e-01
# 25%   -8.906669e-01 -1.026036e+00 -7.557570e-01 -6.701925e-01 -5.812208e-01
# 50%   -8.906669e-01 -1.346266e-01 -2.648979e-01 -6.701925e-01 -5.812208e-01
# 75%    1.005132e+00  9.837522e-01  6.333683e-01  1.492109e+00  1.720516e+00
# max    2.515715e+00  1.011415e+01  7.949291e+00  1.492109e+00  1.720516e+00
#
#                  15            16
# count  8.950000e+03  8.950000e+03
# mean   5.160366e-17 -9.526830e-17
# std    1.000056e+00  1.000056e+00
# min   -5.436904e-01 -5.146250e-01
# 25%   -5.436904e-01 -5.146250e-01
# 50%   -5.436904e-01 -5.146250e-01
# 75%   -5.436904e-01 -5.146250e-01
# max    1.839282e+00  1.943162e+00

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA

# %%
#applying the PCA to find the number of factors

variance_ratio = {}
for n in range(2,18):
    pc = PCA(n_components=n)
    cr_pca = pc.fit(creditcard_scaled)
    variance_ratio[n] = sum(cr_pca.explained_variance_ratio_)

# %%
#ratio of variance explained 
variance_ratio
# Out:
# {2: 0.5824607599200569,
#  3: 0.7297466434636777,
#  4: 0.8113282252273154,
#  5: 0.8768561357190713,
#  6: 0.9184810955062338,
#  7: 0.9409751162847568,
#  8: 0.9615534006293797,
#  9: 0.973944884343926,
#  10: 0.9835980480783886,
#  11: 0.9897248725782226,
#  12: 0.9927531994176744,
#  13: 0.9953959123246203,
#  14: 0.9979644752646767,
#  15: 0.9996366026820453,
#  16: 1.0,
#  17: 1.0}

# %%
#plotting the graph

pd.Series(variance_ratio).plot()
plt.xlabel("No of Components")
plt.ylabel("% of Variance Explained")
plt.show()

# %% [markdown]
# <big>
# - Since 5 Components are explaining about 88% of the variance we select 5 components
# </big>

# %%
final_pc = PCA(n_components=5).fit(creditcard_scaled)

reduced_creditdata = final_pc.fit_transform(creditcard_scaled)

# %%
#main data set has 17 components
creditcard_scaled.shape
# Out:
# (8950, 17)

# %%
#after doing pca we got 5 components
reduced_creditdata.shape
# Out:
# (8950, 5)

# %%
column_names = creditcarddata_new.columns
column_names
# Out:
# Index(['BALANCE_FREQUENCY', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'Monthly_Avg_Purchase',
#        'Monthly_Cash_Advance', 'Balance_Credit_Ratio', 'Total_Payment_Ratio',
#        'Purchase_Type_BOTH_ONEOFF_INSTALLMENTS', 'Purchase_Type_INSTALLMENTS',
#        'Purchase_Type_NONE', 'Purchase_Type_ONEOFF'],
#       dtype='object')

# %% [markdown]
# - Visualizing the reduced factors

# %%
pd.DataFrame(final_pc.components_.T,columns=['PC_' + str(i) for i in range(5)],index=column_names)
# Out:
#                                             PC_0      PC_1      PC_2
# BALANCE_FREQUENCY                       0.029847  0.240297 -0.262754  \
# ONEOFF_PURCHASES                        0.214081  0.405781  0.240049
# INSTALLMENTS_PURCHASES                  0.312163 -0.098002 -0.315571
# PURCHASES_FREQUENCY                     0.345816  0.016014 -0.163088
# ONEOFF_PURCHASES_FREQUENCY              0.214669  0.361716  0.163291
# PURCHASES_INSTALLMENTS_FREQUENCY        0.295541 -0.111518 -0.330038
# CASH_ADVANCE_FREQUENCY                 -0.213932  0.286571 -0.278261
# CASH_ADVANCE_TRX                       -0.229368  0.292065 -0.284771
# PURCHASES_TRX                           0.355594  0.106799 -0.102334
# Monthly_Avg_Purchase                    0.346031  0.141640  0.024457
# Monthly_Cash_Advance                   -0.243821  0.264728 -0.257093
# Balance_Credit_Ratio                   -0.146196  0.236177 -0.251038
# Total_Payment_Ratio                     0.119670  0.021260  0.136472
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  0.241463  0.273826 -0.131235
# Purchase_Type_INSTALLMENTS              0.082251 -0.443104 -0.209437
# Purchase_Type_NONE                     -0.310247 -0.005009 -0.097126
# Purchase_Type_ONEOFF                   -0.042301  0.167066  0.472979
#
#                                             PC_3      PC_4
# BALANCE_FREQUENCY                      -0.353524 -0.228764
# ONEOFF_PURCHASES                        0.001340 -0.023165
# INSTALLMENTS_PURCHASES                  0.087945 -0.002057
# PURCHASES_FREQUENCY                    -0.074366  0.115332
# ONEOFF_PURCHASES_FREQUENCY              0.036587 -0.051420
# PURCHASES_INSTALLMENTS_FREQUENCY        0.023473  0.025880
# CASH_ADVANCE_FREQUENCY                  0.096093  0.360749
# CASH_ADVANCE_TRX                        0.103467  0.332620
# PURCHASES_TRX                          -0.054427  0.104945
# Monthly_Avg_Purchase                   -0.079612  0.194129
# Monthly_Cash_Advance                    0.135247  0.267599
# Balance_Credit_Ratio                   -0.431534 -0.182296
# Total_Payment_Ratio                     0.591509  0.215469
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  0.254705 -0.340640
# Purchase_Type_INSTALLMENTS             -0.190819  0.353823
# Purchase_Type_NONE                      0.245311 -0.342313
# Purchase_Type_ONEOFF                   -0.338769  0.362439

# %%
pd.DataFrame(final_pc.explained_variance_ratio_,columns=["Variance Ratio"],index=["PC_" + str(i) for i in range(5)])
# Out:
#       Variance Ratio
# PC_0        0.401937
# PC_1        0.180524
# PC_2        0.147286
# PC_3        0.081582
# PC_4        0.065528

# %% [markdown]
# #### Loading Matrix
#
# Loadings=Eigenvectors * sqrt(Eigenvalues)
#
# loadings are the covariances/correlations between the original variables and the unit-scaled components.

# %% [markdown]
# ### Clustering
# - Find the optimum number of clusters using Silhoutte Coefficient

# %%
from sklearn import metrics
from sklearn.cluster import KMeans

# %%
scores = []
inertia = []
k_range = range(3, 12)

for k in k_range:
    km = KMeans(n_clusters=k, random_state=2)
    km.fit(creditcard_scaled)
    scores.append(metrics.silhouette_score(creditcard_scaled, km.labels_))
    inertia.append(km.inertia_)
# Out:
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
scores
# Out:
# [0.31677629527868134,
#  0.3883321935622073,
#  0.37761915855698325,
#  0.36635827357507383,
#  0.3447318799457864,
#  0.330819759707984,
#  0.3294924060982644,
#  0.30588511503722565,
#  0.30774845019733005]

# %%
plt.plot(k_range,inertia)
plt.xlabel("Clusters")
plt.ylabel("Inertia in the cluster")
plt.show()

# %%
#plotting the sc scores
plt.plot(k_range,scores)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %% [markdown]
# ### Insights
# - From SC Score, the number of optimal clusters could be 4 or 5

# %% [markdown]
# ### Profiling
# - To find the right clustering we will do profiling for 4, 5 clusters

# %% [markdown]
# ### 4-Cluster Solution

# %%
km_4 = KMeans(n_clusters=4,random_state=123)

# %%
#fitting the Kmeans 
km_4.fit(reduced_creditdata)
km_4.labels_
# Out:
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([3, 1, 0, ..., 3, 1, 0])

# %%
#proportion of labels classified

pd.Series(km_4.labels_).value_counts()
# Out:
# 2    2758
# 3    2229
# 1    2089
# 0    1874
# Name: count, dtype: int64

# %% [markdown]
# <big>
# Plotting the 4 cluster Solution labels
# </big>

# %%
plt.figure(figsize=(10, 8 ))
plt.scatter(reduced_creditdata[:, 0], reduced_creditdata[:, 1], c = km_4.labels_, cmap = "Spectral", alpha = 0.8)
plt.title("PC_1 and PC2 for 4 cluster solution")
plt.show()

# %% [markdown]
# <big>
#     Taking the key performance index variables for analysis
# </big>

# %%
col_key_kpi = ["PURCHASES_TRX","Monthly_Avg_Purchase","Monthly_Cash_Advance","Balance_Credit_Ratio","CASH_ADVANCE_TRX","Total_Payment_Ratio","Purchase_Type_INSTALLMENTS","Purchase_Type_NONE","Purchase_Type_BOTH_ONEOFF_INSTALLMENTS","Purchase_Type_ONEOFF","CREDIT_LIMIT"]

# %%
#making a dataframe with 4 cluster solution labels

cluster_df_4 = pd.concat([creditcarddata_org[col_key_kpi], pd.Series(km_4.labels_,name="Cluster_4")], axis =1)

# %%
cluster_df_4.head()
# Out:
#    PURCHASES_TRX  Monthly_Avg_Purchase  Monthly_Cash_Advance
# 0              2                  7.95                  0.00  \
# 1              0                  0.00                536.91
# 2             12                 64.43                  0.00
# 3              1                124.92                 17.15
# 4              1                  1.33                  0.00
#
#    Balance_Credit_Ratio  CASH_ADVANCE_TRX  Total_Payment_Ratio
# 0                  0.04                 0                 1.45  \
# 1                  0.46                 4                 3.83
# 2                  0.33                 0                 0.99
# 3                  0.22                 1                 0.00
# 4                  0.68                 0                 2.77
#
#    Purchase_Type_INSTALLMENTS  Purchase_Type_NONE
# 0                        True               False  \
# 1                       False                True
# 2                       False               False
# 3                       False               False
# 4                       False               False
#
#    Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_ONEOFF  CREDIT_LIMIT
# 0                                   False                 False        1000.0  \
# 1                                   False                 False        7000.0
# 2                                   False                  True        7500.0
# 3                                   False                  True        7500.0
# 4                                   False                  True        1200.0
#
#    Cluster_4
# 0          3
# 1          1
# 2          0
# 3          0
# 4          0

# %% [markdown]
# #### Grouping the data based on cluster.
#
# #### Mean gives a good indication of the distribution of data. so we are finding the mean for each variable for each cluster

# %%
cluster_4 = cluster_df_4.groupby('Cluster_4').apply(lambda x: x[col_key_kpi].mean()).T
cluster_4
# Out:
# Cluster_4                                         0            1            2
# PURCHASES_TRX                              7.118997     0.044998    33.125453  \
# Monthly_Avg_Purchase                      69.758170     0.157688   193.696041
# Monthly_Cash_Advance                      77.843474   186.380235    67.620018
# Balance_Credit_Ratio                       0.378629     0.576103     0.354572
# CASH_ADVANCE_TRX                           2.864995     6.553854     2.807107
# Total_Payment_Ratio                        5.561393     9.931565     7.268709
# Purchase_Type_INSTALLMENTS                 0.000000     0.016754     0.000000
# Purchase_Type_NONE                         0.000000     0.977501     0.000000
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS     0.003735     0.002393     1.000000
# Purchase_Type_ONEOFF                       0.996265     0.003351     0.000000
# CREDIT_LIMIT                            4512.905630  4056.949100  5750.015566
#
# Cluster_4                                         3
# PURCHASES_TRX                             12.049349
# Monthly_Avg_Purchase                      47.553876
# Monthly_Cash_Advance                      33.481377
# Balance_Credit_Ratio                       0.264459
# CASH_ADVANCE_TRX                           1.020637
# Total_Payment_Ratio                       13.397622
# Purchase_Type_INSTALLMENTS                 0.998205
# Purchase_Type_NONE                         0.000000
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS     0.001795
# Purchase_Type_ONEOFF                       0.000000
# CREDIT_LIMIT                            3334.739067

# %%
def ClusterPercentage(datafr,name):
    """Common utility function to calculate the percentage and size of cluster"""
    
    size = pd.Series(datafr[name].value_counts().sort_index())
    percent = pd.Series(round(datafr[name].value_counts()/datafr.shape[0] * 100,2)).sort_index()

    size_df = pd.concat([size, percent],axis=1)
    size_df.columns = ["Cluster_Size","Cluster_Percentage"]
    
    return(size_df)

# %%
ClusterPercentage(cluster_df_4,"Cluster_4")
# Out:
#            Cluster_Size  Cluster_Percentage
# Cluster_4
# 0                  1874               20.94
# 1                  2089               23.34
# 2                  2758               30.82
# 3                  2229               24.91

# %%
#transposing the cluster
cluster_4_T = cluster_4.T

# %%
cluster_4_T
# Out:
#            PURCHASES_TRX  Monthly_Avg_Purchase  Monthly_Cash_Advance
# Cluster_4
# 0               7.118997             69.758170             77.843474  \
# 1               0.044998              0.157688            186.380235
# 2              33.125453            193.696041             67.620018
# 3              12.049349             47.553876             33.481377
#
#            Balance_Credit_Ratio  CASH_ADVANCE_TRX  Total_Payment_Ratio
# Cluster_4
# 0                      0.378629          2.864995             5.561393  \
# 1                      0.576103          6.553854             9.931565
# 2                      0.354572          2.807107             7.268709
# 3                      0.264459          1.020637            13.397622
#
#            Purchase_Type_INSTALLMENTS  Purchase_Type_NONE
# Cluster_4
# 0                            0.000000            0.000000  \
# 1                            0.016754            0.977501
# 2                            0.000000            0.000000
# 3                            0.998205            0.000000
#
#            Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_ONEOFF
# Cluster_4
# 0                                        0.003735              0.996265  \
# 1                                        0.002393              0.003351
# 2                                        1.000000              0.000000
# 3                                        0.001795              0.000000
#
#            CREDIT_LIMIT
# Cluster_4
# 0           4512.905630
# 1           4056.949100
# 2           5750.015566
# 3           3334.739067

# %%
def ClusterAnalysis(datafr):
    """A function to analyze the KPI variables across each segment in the cluster and returns dataframe useful for plotting"""
    
    #Build a dataframe of KPI for each cluster suitable for plotting
    n = datafr.shape[0]
    
    mn_cash_advnce = pd.Series(np.log(datafr.reset_index(drop = True)["Monthly_Cash_Advance"]))
    balance_crdt_ratio = pd.Series(datafr.reset_index(drop = True)["Balance_Credit_Ratio"])
    mn_avg_purchases = pd.Series(np.log(datafr.reset_index(drop = True)["Monthly_Avg_Purchase"]))
    total_pymnt_ratio = pd.Series(datafr.reset_index(drop = True)["Total_Payment_Ratio"])
    installment = pd.Series(datafr.reset_index(drop = True)["Purchase_Type_INSTALLMENTS"])
    oneoff = pd.Series(datafr.reset_index(drop = True)["Purchase_Type_ONEOFF"])

    final_df = pd.concat([mn_cash_advnce,mn_avg_purchases,balance_crdt_ratio,total_pymnt_ratio,installment,oneoff],axis=1)
    final_df.columns=["Monthly_Cash_Advance","Monthly_Avg_Purchase","Balance_Credit_Ratio","Total_Payment_Ratio","Installments","Oneoff"]
    final_df.index = ["Cl-"+ str(i) for i in range(n)]
    return(final_df)

# %%
final_df_4 = ClusterAnalysis(cluster_4_T)
final_df_4
# Out:
#       Monthly_Cash_Advance  Monthly_Avg_Purchase  Balance_Credit_Ratio
# Cl-0              4.354700              4.245035              0.378629  \
# Cl-1              5.227789             -1.847138              0.576103
# Cl-2              4.213904              5.266290              0.354572
# Cl-3              3.510989              3.861863              0.264459
#
#       Total_Payment_Ratio  Installments    Oneoff
# Cl-0             5.561393      0.000000  0.996265
# Cl-1             9.931565      0.016754  0.003351
# Cl-2             7.268709      0.000000  0.000000
# Cl-3            13.397622      0.998205  0.000000

# %%
final_df_4.plot(kind = "bar")
#plt.xticks(["11","22","33","44"])
plt.show()

# %% [markdown]
# ### Insights with 4 Clusters
# ----
# <big>
# - Cluster 0 is the group of customers who have the highest Montly Average Purchases and doing both installment and one off purchases. **This group is about 31% of the total customer base**
# - Cluster 1 customers are doing  maximum one off payments and least total payment ratio. **This group is about 21% of the total customer base**
# - Cluster 2 customers have lowest balance to credit ratio (good credit score) and are paying dues also doing maximum installment purchases. **This group is about 25% of the total customer base**
# - Cluster 3 customers are taking maximum advance cash and has high debt to credit ratio (poor credit rating) & not doing any purchase transcation.**This group is about 23% of the total customer base**
#
# ----

# %% [markdown]
# ### 5 Cluster Solution

# %%
km_5 = KMeans(n_clusters=5,random_state=123)
km_5.fit(reduced_creditdata)
# Out:
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=123)

# %%
km_5.labels_
# Out:
# array([4, 1, 0, ..., 4, 1, 0])

# %%
#distribution of labels

pd.Series(km_5.labels_).value_counts()
# Out:
# 4    2130
# 1    2084
# 2    1985
# 0    1860
# 3     891
# Name: count, dtype: int64

# %% [markdown]
# <big>
# Plotting the 5 Cluster Solution Labels
# </big>

# %%
plt.figure(figsize=(10,8))
plt.scatter(reduced_creditdata[:,0],reduced_creditdata[:,1],c=km_5.labels_,cmap="Spectral",alpha = 0.7)
plt.xlabel("PC_0 & PC_1")
plt.show()

# %%
#5 cluster dataframe with labels

cluster_df_5 = pd.concat([creditcarddata_org[col_key_kpi],pd.Series(km_5.labels_,name="Cluster_5")], axis = 1)

# %%
cluster_df_5.head()
# Out:
#    PURCHASES_TRX  Monthly_Avg_Purchase  Monthly_Cash_Advance
# 0              2                  7.95                  0.00  \
# 1              0                  0.00                536.91
# 2             12                 64.43                  0.00
# 3              1                124.92                 17.15
# 4              1                  1.33                  0.00
#
#    Balance_Credit_Ratio  CASH_ADVANCE_TRX  Total_Payment_Ratio
# 0                  0.04                 0                 1.45  \
# 1                  0.46                 4                 3.83
# 2                  0.33                 0                 0.99
# 3                  0.22                 1                 0.00
# 4                  0.68                 0                 2.77
#
#    Purchase_Type_INSTALLMENTS  Purchase_Type_NONE
# 0                        True               False  \
# 1                       False                True
# 2                       False               False
# 3                       False               False
# 4                       False               False
#
#    Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_ONEOFF  CREDIT_LIMIT
# 0                                   False                 False        1000.0  \
# 1                                   False                 False        7000.0
# 2                                   False                  True        7500.0
# 3                                   False                  True        7500.0
# 4                                   False                  True        1200.0
#
#    Cluster_5
# 0          4
# 1          1
# 2          0
# 3          0
# 4          0

# %%
#calculating the mean of all variables in the cluster

cluster_5 = cluster_df_5.groupby("Cluster_5").apply(lambda x: x[col_key_kpi].mean()).T
cluster_5
# Out:
# Cluster_5                                         0            1            2
# PURCHASES_TRX                              7.067742     0.035509    34.533501  \
# Monthly_Avg_Purchase                      68.685618     0.096569   209.710831
# Monthly_Cash_Advance                      73.635694   185.109535     3.988166
# Balance_Credit_Ratio                       0.377468     0.576291     0.262962
# CASH_ADVANCE_TRX                           2.648387     6.454894     0.152141
# Total_Payment_Ratio                        5.540070     9.950029     8.569078
# Purchase_Type_INSTALLMENTS                 0.000000     0.016795     0.000000
# Purchase_Type_NONE                         0.000000     0.979846     0.000000
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS     0.003226     0.000000     1.000000
# Purchase_Type_ONEOFF                       0.996774     0.003359     0.000000
# CREDIT_LIMIT                            4489.884489  4047.344851  5716.152610
#
# Cluster_5                                         3            4
# PURCHASES_TRX                             27.546577    11.896714
# Monthly_Avg_Purchase                     141.879293    47.239690
# Monthly_Cash_Advance                     252.419820    19.154812
# Balance_Credit_Ratio                       0.594658     0.246723
# CASH_ADVANCE_TRX                          10.520763     0.480282
# Total_Payment_Ratio                        3.921919    13.866221
# Purchase_Type_INSTALLMENTS                 0.106622     1.000000
# Purchase_Type_NONE                         0.000000     0.000000
# Purchase_Type_BOTH_ONEOFF_INSTALLMENTS     0.878788     0.000000
# Purchase_Type_ONEOFF                       0.014590     0.000000
# CREDIT_LIMIT                            5863.748597  3223.856047

# %%
#transposing the cluster
cluster_5_T = cluster_5.T
cluster_5_T
# Out:
#            PURCHASES_TRX  Monthly_Avg_Purchase  Monthly_Cash_Advance
# Cluster_5
# 0               7.067742             68.685618             73.635694  \
# 1               0.035509              0.096569            185.109535
# 2              34.533501            209.710831              3.988166
# 3              27.546577            141.879293            252.419820
# 4              11.896714             47.239690             19.154812
#
#            Balance_Credit_Ratio  CASH_ADVANCE_TRX  Total_Payment_Ratio
# Cluster_5
# 0                      0.377468          2.648387             5.540070  \
# 1                      0.576291          6.454894             9.950029
# 2                      0.262962          0.152141             8.569078
# 3                      0.594658         10.520763             3.921919
# 4                      0.246723          0.480282            13.866221
#
#            Purchase_Type_INSTALLMENTS  Purchase_Type_NONE
# Cluster_5
# 0                            0.000000            0.000000  \
# 1                            0.016795            0.979846
# 2                            0.000000            0.000000
# 3                            0.106622            0.000000
# 4                            1.000000            0.000000
#
#            Purchase_Type_BOTH_ONEOFF_INSTALLMENTS  Purchase_Type_ONEOFF
# Cluster_5
# 0                                        0.003226              0.996774  \
# 1                                        0.000000              0.003359
# 2                                        1.000000              0.000000
# 3                                        0.878788              0.014590
# 4                                        0.000000              0.000000
#
#            CREDIT_LIMIT
# Cluster_5
# 0           4489.884489
# 1           4047.344851
# 2           5716.152610
# 3           5863.748597
# 4           3223.856047

# %%
ClusterPercentage(cluster_df_5,"Cluster_5")
# Out:
#            Cluster_Size  Cluster_Percentage
# Cluster_5
# 0                  1860               20.78
# 1                  2084               23.28
# 2                  1985               22.18
# 3                   891                9.96
# 4                  2130               23.80

# %%
final_df_5 = ClusterAnalysis(cluster_5_T)
final_df_5
# Out:
#       Monthly_Cash_Advance  Monthly_Avg_Purchase  Balance_Credit_Ratio
# Cl-0              4.299130              4.229540              0.377468  \
# Cl-1              5.220948             -2.337496              0.576291
# Cl-2              1.383332              5.345730              0.262962
# Cl-3              5.531094              4.954977              0.594658
# Cl-4              2.952554              3.855234              0.246723
#
#       Total_Payment_Ratio  Installments    Oneoff
# Cl-0             5.540070      0.000000  0.996774
# Cl-1             9.950029      0.016795  0.003359
# Cl-2             8.569078      0.000000  0.000000
# Cl-3             3.921919      0.106622  0.014590
# Cl-4            13.866221      1.000000  0.000000

# %%
final_df_5.plot(kind = "bar")

plt.show()

# %% [markdown]
# ### Insights with 5 Clusters
# ----
# <big>
#
# - We have a group of customers (cluster-2) having highest average purchases but there is cluster-3 also having highest cash advance and second highest purchase behaviour but their type of purchases are same
#
# - Cluster 1 and Cluster 3 are behaving similar interms of balance to credit ratio and their monthly cash advances is also on higher side
# ----
# **So we don't have quite distinquisble characters with 5 clusters**

# %% [markdown]
# ## Marketing Strategy Suggested Cluster 4
# ---
#
# ###  Group 0
#    - This is performing best among all the clusters are maintaining highest monthly average purchases. Giving any reward points might increase their purchases.
#
# ### Group 1
#    - This group is doing maximum oneoff payments(may be for bills only). Customers of this group can be offered discount/offer on next transactions upon full payment.
#
# ### Group 2
#    - They are potential target customers who are paying bills and doing purchases and maintaining comparatively good credit score. So we can increase credit limit or can lower down interest rate. Promote premium cards/loyality cars to increase transcations.
#
# ### Group 3
#    - These customers are taking maximum cash advance, these customers should be given remainders for payments. Offers can be provided on early payments to improve their payment rate.

# %%
#fitting the Kmeans 
km_4.fit(creditcarddata_new)
km_4.labels_
# Out:
# c:\Users\bhuvv\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([2, 0, 3, ..., 2, 0, 3])

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\bhuvv\appdata\local\programs\python\python311\lib\site-packages (1.2.0)
# [notice] A new release of pip available: 22.3.1 -> 23.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import joblib# load the model from the file
joblib.dump(km_4, "km_4_model.joblib")
# Out:
# ['km_4_model.joblib']
